# %%
import numpy as np
marks = np.array([60,80,75,90])
print(marks)
# Out:
# [60 80 75 90]

# %%
#vectorization
bonus_marks = marks+5
print(bonus_marks)
# Out:
# [65 85 80 95]

# %%
print(np.mean(marks))
print(np.max(marks))
print(np.min(marks))
# Out:
# 76.25
# 90
# 60

# %%
acc = np.array([0.85, 0.92, 0.78, 0.95, 0.88])
per = acc*100
print(per)
print(np.mean(per))
# Out:
# [85. 92. 78. 95. 88.]
# 87.6

# %%
data = np.array([[10,20,30],[40,50,60]])
print(data)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
data.shape
# Out:
# (2, 3)

# %%
data = np.array([[1,2],[3,4]])
print(data)
print(data.shape)
print(data *10)
print(data[0,0])
# Out:
# [[1 2]
#  [3 4]]
# (2, 2)
# [[10 20]
#  [30 40]]
# 1
