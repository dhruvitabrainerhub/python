# %%
dic = 10*(1/0)
print(dic)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dic = 10*(1/0)
#       2 print(dic)
#
# ZeroDivisionError: division by zero

# %%
4 + spam*3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 4 + spam*3
#
# NameError: name 'spam' is not defined

# %%
'2'+4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 '2'+4
#
# TypeError: can only concatenate str (not "int") to str

# %%
while True:
    try:
        x = int(input("enter the number"))
        break
    except ValueError:
        print("oops that was no valid number ! pls try again")
# Out:
# oops that was no valid number ! pls try again
# oops that was no valid number ! pls try again
# oops that was no valid number ! pls try again
# oops that was no valid number ! pls try again

# %%
class B(Exception):
    pass

class C(B):
    pass

class D(C):
    pass

for cls in [B,C,D]:
    try:
        raise cls()
    except D:
        print("D")
    except C:
        print("C")
    except B:
        print("B")
# Out:
# B
# C
# D

# %%
try:
    raise Exception('spam','eggs')
except Exception as inst:
    print(type(inst))
    print(inst.args)
    print(inst)

    x,y = inst.args
    print('x =' ,x)
    print('y =', y)
# Out:
# <class 'Exception'>
# ('spam', 'eggs')
# ('spam', 'eggs')
# x = spam
# y = eggs

# %%
try:
    f = open("myfile.txt")
    s = f.readline()
    i = int(s.strip())
except OSError as err:
    print("OS Error :",err)
except ValueError:
    print("could not convert data to an integer.")
except Exception as err:
    print(f"Unexpected {err=},{type(err)=}")
    raise
# Out:
# could not convert data to an integer.

# %%
import sys
for arg in sys.argv[1:]:
    try:
        f = open(arg, 'r')
    except OSError:
        print('cannot open', arg)
    else:
        print(arg, 'has', len(f.readlines()), 'lines')
        f.close()
# Out:
# cannot open --f=c:\Users\Shrim\AppData\Roaming\jupyter\runtime\kernel-v37157b512b0171edb93bf5fcdee75456cd5dbd643.json

# %%
for arg in sys.argv[1:]:
    try:
        f =open(arg,"r")
    except OSError:
        print("CANNot open",arg)
    else:
        print(arg,"has",len(f.readlines()),"lines")
        f.close()
# Out:
# CANNot open --f=c:\Users\Shrim\AppData\Roaming\jupyter\runtime\kernel-v37157b512b0171edb93bf5fcdee75456cd5dbd643.json

# %%
def this_fails():
    x = 1/0
try:
    this_fails()
except ZeroDivisionError as err:
    print("handling zerodevision error:",err)
# Out:
# handling zerodevision error: division by zero

# %%
raise NameError ('Hi there')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 raise NameError ('Hi there')
#
# NameError: Hi there

# %%
try:
    raise NameError ("Hi there")
except NameError:
    print("An exception flew by !")
    raise
# Out:
# An exception flew by !
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 try:
# ----> 2     raise NameError ("Hi there")
#       3 except NameError:
#       4     print("An exception flew by !")
#
# NameError: Hi there

# %%
try:
    open("database.sqlite")
except OSError:
    raise RuntimeError("uable to handle error")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 2
#       1 try:
# ----> 2     open("database.sqlite")
#       3 except OSError:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'database.sqlite'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[33], line 4
#       2     open("database.sqlite")
# ...

# %%
raise RuntimeError from exc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 raise RuntimeError from exc
#
# NameError: name 'exc' is not defined

# %%
def func():
    raise ConnectionError
try:
    func()
except ConnectionError as exc:
    raise RuntimeError('Failed to open database') from exc
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[36], line 4
#       3 try:
# ----> 4     func()
#       5 except ConnectionError as exc:
#
# Cell In[36], line 2, in func()
#       1 def func():
# ----> 2     raise ConnectionError
#
# ConnectionError:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[36], line 6
#       4     func()
#       5 except ConnectionError as exc:
# ----> 6     raise RuntimeError('Failed to open database') from exc
#
# RuntimeError: Failed to open database

# %%
try:
    open('database.sqlite')
except OSError:
    raise RuntimeError from None
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[37], line 4
#       2     open('database.sqlite')
#       3 except OSError:
# ----> 4     raise RuntimeError from None
#
# RuntimeError:

# %%
class AgeError(Exception):
    pass
age = -5
if age<0:
    raise AgeError("age cannot be negative")
else:
    print(age)
# Out:
# ---------------------------------------------------------------------------
# AgeError                                  Traceback (most recent call last)
# Cell In[43], line 5
#       3 age = -5
#       4 if age<0:
# ----> 5     raise AgeError("age cannot be negative")
#       6 else:
#       7     print(age)
#
# AgeError: age cannot be negative

# %%
class BalanceError(Exception):
    pass
class BankSystemError(Exception):
    pass
def withdraw(balance,amount):
    if amount>balance:
        raise BalanceError("Not enough amount")
    return balance - amount
try:
    balance = 3300
    amount = 4000
    new = withdraw(balance,amount)
    print("New Balance",new)
except BalanceError as e:
    raise BankSystemError("Transaction Failed") from e
# Out:
# ---------------------------------------------------------------------------
# BalanceError                              Traceback (most recent call last)
# Cell In[48], line 12
#      11 amount = 4000
# ---> 12 new = withdraw(balance,amount)
#      13 print("New Balance",new)
#
# Cell In[48], line 7, in withdraw(balance, amount)
#       6 if amount>balance:
# ----> 7     raise BalanceError("Not enough amount")
#       8 return balance - amount
#
# BalanceError: Not enough amount
#
# The above exception was the direct cause of the following exception:
#
# BankSystemError                           Traceback (most recent call last)
# Cell In[48], line 15
#      13     print("New Balance",new)
#      14 except BalanceError as e:
# ---> 15     raise BankSystemError("Transaction Failed") from e
#
# BankSystemError: Transaction Failed

# %%
try:
    raise KeyboardInterrupt
finally:
    print("Goodbye, world!")
# Out:
# Goodbye, world!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 2
#       1 try:
# ----> 2     raise KeyboardInterrupt
#       3 finally:
#       4     print("Goodbye, world!")
#
# KeyboardInterrupt:

# %%
def bool_return():
    try:
        return True
    finally:
        return False
bool_return()
# Out:
# False

# %%
def divide(x,y):
    try:
        result = x/y
    except ZeroDivisionError:
        print("division by zero!")
    else:
        print("Result is: ",result)
    finally:
        print("executing finally clause")
divide(3,"0")
# Out:
# executing finally clause
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 10
#       8     finally:
#       9         print("executing finally clause")
# ---> 10 divide(3,"0")
#
# Cell In[60], line 3, in divide(x, y)
#       1 def divide(x,y):
#       2     try:
# ----> 3         result = x/y
#       4     except ZeroDivisionError:
#       5         print("division by zero!")
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
def read_file():
    try:
        f = open("dataa.txt","r")
        read = f.read()
        print(read)
    except FileNotFoundError:
        print("File Not Found!")
    finally:
        print("file closing......")
        f.close()
read_file()
# Out:
# File Not Found!
# file closing......
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[64], line 11
#       9         print("file closing......")
#      10         f.close()
# ---> 11 read_file()
#
# Cell In[64], line 10, in read_file()
#       8 finally:
#       9     print("file closing......")
# ---> 10     f.close()
#
# UnboundLocalError: cannot access local variable 'f' where it is not associated with a value

# %%
def connect_server():
    connection = None
    try:
        print("connecting to server...")
        connection = "server connected"
        print("connected server")
    finally:
        print("Clossing connection..")
connect_server()
# Out:
# connecting to server...
# connected server
# Clossing connection..

# %%
for line in open("data.txt"):
    print(line)
# Out:
# hello Good Morning!  My name is dhruvita and my age is 21  i am recently graduated n bsc it data management and visual insight from GU.

# %%
with open("data.txt","r") as f:
    for line in f:
        print(line)
#Automatic close file
# Out:
# hello Good Morning!  My name is dhruvita and my age is 21  i am recently graduated n bsc it data management and visual insight from GU.

# %%
def f():
    excs = [OSError("error 1"),NameError("error 2")]
    raise ExceptionGroup("there was problem",excs)
f()
try:
    f()
except Exception as e:
    print(f'caught {type(e)} : e')
# Out:
#   + Exception Group Traceback (most recent call last):
#   |   File "C:\Users\Shrim\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py", line 3701, in run_code
#   |     exec(code_obj, self.user_global_ns, self.user_ns)
#   |     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   |   File "C:\Users\Shrim\AppData\Local\Temp\ipykernel_17456\1481873955.py", line 4, in <module>
#   |     f()
#   |     ~^^
#   |   File "C:\Users\Shrim\AppData\Local\Temp\ipykernel_17456\1481873955.py", line 3, in f
#   |     raise ExceptionGroup("there was problem",excs)
#   | ExceptionGroup: there was problem (2 sub-exceptions)
#   +-+---------------- 1 ----------------
#     | OSError: error 1
#     +---------------- 2 ----------------
#     | NameError: error 2
#     +------------------------------------

# %%
class Test:
    def __init__(self, name, should_fail):
        self.name = name
        self.should_fail = should_fail

    def run(self):
        print(f"Running {self.name}")
        if self.should_fail:
            raise ValueError(f"{self.name} failed!")
        print(f"{self.name} passed!")


tests = [
    Test("Test1", False),
    Test("Test2", True),
    Test("Test3", True),
]

excs = []

for test in tests:
    try:
        test.run()
    except Exception as e:
        excs.append(e)

if excs:
    raise ExceptionGroup("Test Failures", excs)
# Out:
# Running Test1
# Test1 passed!
# Running Test2
# Running Test3
#   + Exception Group Traceback (most recent call last):
#   |   File "C:\Users\Shrim\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py", line 3701, in run_code
#   |     exec(code_obj, self.user_global_ns, self.user_ns)
#   |     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   |   File "C:\Users\Shrim\AppData\Local\Temp\ipykernel_17456\2320903893.py", line 28, in <module>
#   |     raise ExceptionGroup("Test Failures", excs)
#   | ExceptionGroup: Test Failures (2 sub-exceptions)
#   +-+---------------- 1 ----------------
#     | Traceback (most recent call last):
#     |   File "C:\Users\Shrim\AppData\Local\Temp\ipykernel_17456\2320903893.py", line 23, in <module>
#     |     test.run()
#     |     ~~~~~~~~^^
#     |   File "C:\Users\Shrim\AppData\Local\Temp\ipykernel_17456\2320903893.py", line 9, in run
#     |     raise ValueError(f"{self.name} failed!")
# ...

# %%
def f():
    raise ExceptionGroup("group1",[OSError(1),SystemError(2),
                                   ExceptionGroup("group2",[
                                       OSError(3),
                                       RecursionError(4)])])
try:
    f()
except* OSError as e:
    print("there were OsError")
except* SystemError as e:
    print("there were system Error")
# Out:
# there were OsError
# there were system Error
#   + Exception Group Traceback (most recent call last):
#   |   File "C:\Users\Shrim\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py", line 3701, in run_code
#   |     exec(code_obj, self.user_global_ns, self.user_ns)
#   |     ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   |   File "C:\Users\Shrim\AppData\Local\Temp\ipykernel_17456\2905997204.py", line 7, in <module>
#   |     f()
#   |     ~^^
#   |   File "C:\Users\Shrim\AppData\Local\Temp\ipykernel_17456\2905997204.py", line 2, in f
#   |     raise ExceptionGroup("group1",[OSError(1),SystemError(2),
#   |     ...<2 lines>...
#   |                                        RecursionError(4)])])
#   | ExceptionGroup: group1 (1 sub-exception)
#   +-+---------------- 1 ----------------
#     | ExceptionGroup: group2 (1 sub-exception)
#     +-+---------------- 1 ----------------
#       | RecursionError: 4
#       +------------------------------------

# %%
def ageerror(age):
        if age<18:
            raise ValueError("not age")
ageerror(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[100], line 4
#       2         if age<18:
#       3             raise ValueError("not age")
# ----> 4 ageerror(10)
#
# Cell In[100], line 3, in ageerror(age)
#       1 def ageerror(age):
#       2         if age<18:
# ----> 3             raise ValueError("not age")
#
# ValueError: not age

# %%
try:
    raise NameError("something went wrong")
except NameError:
    print("Error Caught")
    raise
# Out:
# Error Caught
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 2
#       1 try:
# ----> 2     raise NameError("something went wrong")
#       3 except NameError:
#       4     print("Error Caught")
#
# NameError: something went wrong

# %%
class InvalidPasswordError(Exception):
    pass
password = "45454"
try:

    if len(password)<6:
        raise InvalidPasswordError("passwerd too short")
except Exception as e:
    print("Invalid Password Error",e)
    raise
InvalidPasswordError()
# Out:
# Invalid Password Error passwerd too short
# ---------------------------------------------------------------------------
# InvalidPasswordError                      Traceback (most recent call last)
# Cell In[110], line 7
#       4 try:
#       6     if len(password)<6:
# ----> 7         raise InvalidPasswordError("passwerd too short")
#       8 except Exception as e:
#       9     print("Invalid Password Error",e)
#
# InvalidPasswordError: passwerd too short

# %%
def file():
    try:
        with open("data.txt","r") as f:
            print(f.readline())
    finally:
        print("file closed")
        f.close()
file()
# Out:
# hello Good Morning!  My name is dhruvita and my age is 21  i am recently graduated n bsc it data management and visual insight from GU.
# file closed

# %%
def over():
    try:
        return False
    finally:
        return True
over()
# Out:
# True

# %%
f = open("data.txt","r")
print(f.read())
print(f.close()
# Out:
# hello Good Morning!  My name is dhruvita and my age is 21  i am recently graduated n bsc it data management and visual insight from GU.
