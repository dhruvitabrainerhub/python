# %%
class Student:
    pass
rr = type(Student)

# %%
class Father:
    def skill1(self):
        print("cooking")
class Mother:
    def skill2(self):
        print("driving")
class Child(Father,Mother):
    print("hello")                  
c = Child()
c.skill1()
c.skill2()
# Out:
# hello
# cooking
# driving

# %%
class Animal:
    def sound(self):
        print("Animals")
class Dog(Animal):
    def sound(self):
        print("barks")

d = Dog()
d.sound()
# Out:
# barks

# %%
a = [2,1,3]
b = a
print(a)
b.append(4)
print(a,b)
# Out:
# [2, 1, 3]
# [2, 1, 3, 4] [2, 1, 3, 4]

# %%
x = 10

def test():
    x = 20
    
test()
print(x)
# Out:
# 10

# %%
x = 10

def test():
    global x
    x = 20

test()
print(x)
# Out:
# 20

# %%
def scope_test():
    def do_local():
        spam = "local spam"

    def do_nonlocal():
        nonlocal spam
        spam = "nonlocal spam"

    def do_global():
        global spam
        spam = "global spam"

    spam = "test spam"
    do_local()
    print("After local assignment:", spam)
    do_nonlocal()
    print("After nonlocal assignment:", spam)
    do_global()
    print("After global assignment:", spam)

scope_test()
print("In global scope:", spam)
# Out:
# After local assignment: test spam
# After nonlocal assignment: nonlocal spam
# After global assignment: nonlocal spam
# In global scope: global spam

# %%
x = 5

def outer():
    x = 10

    def inner():
        global x
        x = 50

    inner()
    print("Outer x:", x)

outer()
print("Global x:", x)
# Out:
# Outer x: 10
# Global x: 50

# %%
x = 100

def outer():
    x = 50

    def inner1():
        x = 30

    def inner2():
        nonlocal x
        x = 20

    def inner3():
        global x
        x = 10

    inner1()
    print("After inner1:", x)

    inner2()
    print("After inner2:", x)

    inner3()
    print("After inner3:", x)

outer()
print("Global x:", x)
# Out:
# After inner1: 50
# After inner2: 20
# After inner3: 20
# Global x: 10

# %%
x = 5

def outer():
    def inner():
        print(x) #because first print and after assign x value is 10
        x = 10

    inner()

outer()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[10], line 10
#       6         x = 10
#       8     inner()
# ---> 10 outer()
#
# Cell In[10], line 8, in outer()
#       5     print(x) #because first print and after assign x value is 10
#       6     x = 10
# ----> 8 inner()
#
# Cell In[10], line 5, in outer.<locals>.inner()
#       4 def inner():
# ----> 5     print(x) #because first print and after assign x value is 10
#       6     x = 10
#
# UnboundLocalError: local variable 'x' referenced before assignment

# %%
x = 5

def outer():
    x = 10  # outer variable

    def inner():
        nonlocal x  # target outer variable
        print("Before change:", x)
        x = 20       # change outer variable
        print("After change:", x)

    inner()
    print("Outer x after inner():", x)

outer()
print("Global x:", x)
# Out:
# Before change: 10
# After change: 20
# Outer x after inner(): 20
# Global x: 5

# %%
x=5 
def outer():
    x = 10
    def inner():
        nonlocal x
        print("Before Change:",x)
        x = 20
        print("after change: ",x)
    inner()
    print("outer x after inner():",x)
outer()
print("global x:",x)
# Out:
# Before Change: 10
# after change:  20
# outer x after inner(): 20
# global x: 5

# %%
class Myclass:
    i = 12345
    def f(self):
        print("my world")

    def __init__(self):
        self.data = []

x = Myclass()

# %%
class Complex:
    def __init__(self,read,image):
        self.r = read
        self.i = image
y = Complex(3.0,-4.5)
print(y.r , y.i)
# Out:
# 3.0 -4.5

# %%
# attribute reference
y.counter = 1
while y.counter<10:
    y.counter =y.counter*2
print(y.counter)
del y.counter
# Out:
# 16

# %%
type(x)
dir(x)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'data',
#  'f',
#  'i']

# %%
x.f()
xf = x.f()
while True:
    print(xf)
    break
# Out:
# my world
# my world
# None

# %%
class Dog:
    kind = "canine"
    def __init__(self,name):
        self.name = name
d = Dog('fido')
e = Dog('buddy')
print(d.kind)
print(d.name)
print(e.name)
# Out:
# canine
# fido
# buddy

# %%
class Dog:
    tricks =[]
    def __init__(self,name):
        self.name = name
    
    def add_trick(self,trick):
        self.tricks.append(trick)

d = Dog('fido')
e = Dog('buddy')
d.add_trick('hello')
e.add_trick('say')
d.tricks
# Out:
# ['hello', 'say']

# %%
class Dog:
    def __init__(self,name):
        self.name = name
        self.tricks = []
    
    def add_trick(self,trick):
        self.tricks.append(trick)
d = Dog('fido')
e = Dog('Buddy')
d.add_trick('roll over')
d.tricks
e.add_trick('play dead')
d.tricks
e.tricks
# Out:
# ['play dead']

# %%
class Warehouse:
    purpose = 'store'
    region = 'west'
w1 = Warehouse()
w1.purpose,w1.region
w2 = Warehouse()
w2.purpose = 'store container'
w2.purpose, w2.region
# Out:
# ('store container', 'west')

# %%
# Function defined outside the class
def f1(self, x, y):
    return min(x, x+y)

class C:
    f = f1

    def g(self):
        return 'hello world'

    h = g
c = C()
c.f(2,3)
c.h()
# Out:
# 'hello world'

# %%
class Bag:
    def __init__(self):
        self.data = []
    def add(self,x):
        self.data.append(x)
    def addtwice(self,x):
        self.add(x)
        self.add(y)
b = Bag()
b.add(2)
b.addtwice(45)
b.add(4)
b.data
# Out:
# [2, 45, <__main__.Complex at 0x1a5139165f0>, 4]

# %%
class Employee:
    def __init__(self,name):
        self.name = name
    
    def work(self):
        return "Employee is working"
    
class Developer(Employee):
    def code(self):
        return "Developer is coding"

c=Developer("Alina")
c.name
c.code()
c.work()
# Out:
# 'Employee is working'

# %%
class Bag:
    def __init__(self):
        self.data = []
b1 = Bag()
b2 = Bag()

# %%
class Bag:
    data = []

    def add(self, x):
        self.data.append(x)

b1 = Bag()
b2 = Bag()

b1.add(5)
print(b1.data)
print(b2.data)
# Out:
# [5]
# [5]

# %%
class A:
    def show(self):
        print("A")
class B(A):
    pass
class C(B):
    def show(self):
        print("B")
c= C()
c.show()
# Out:
# B

# %%
#multiple inheritance
class A:
    def show(self):
        print("A")
class B:
    def display(self):
        print("B")
class C(A,B):
    pass
c = C()
c.show()
c.display()
# Out:
# A
# B

# %%
class A:
    def show(self):
        print("A")
class B(A):
    def show(self):
        print("B")
        super().show()
class C(A):
    def show(self):
        print("C")
        super().show()
class D(B,C):
    def show(self):
        print("D")
        super().show()

d = D()
d.show()
# Out:
# D
# B
# C
# A

# %%
class Student:
    def __init__(self):
        self.__marks = 90
s = Student()

print(s._Student__marks) #if use outside the class so this is method
s.__marks # because this is name mangling so not allow call outside the class
# Out:
# 90
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 7
#       5 # because this is name mangling so not allow call outside the class
#       6 print(s._Student__marks)
# ----> 7 s.__marks
#
# AttributeError: 'Student' object has no attribute '__marks'

# %%
#making a private method
class Mapping:
    def __init__(self,iterable):
        self.items_list = []
        self.__update(iterable)
    def update(self,iterable):
        for item in iterable:
            self.items_list.append(item)
    __update = update
class Mappingsubclass(Mapping):
    def update(self,key,value):
        for item in zip(key,value):
            self.items_list.append(item)

m = Mapping([1,2])
m.items_list

m = Mappingsubclass([1,2,3,4])
m.items_list
m.update([1,2],[3,4])
m.items_list
# Out:
# [1, 2, 3, 4, (1, 3), (2, 4)]

# %%
s = 'abc'
it = iter(s)
next(it)
next(it)
# Out:
# 'b'

# %%
class Countdown:
    def __init__(self, start):
        self.current = start

    def __iter__(self):
        return self

    def __next__(self):
        if self.current <= 0:
            raise StopIteration

        num = self.current
        self.current -= 1
        return num


c = Countdown(5)

for number in c:
    print(number)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
c = Countdown(3)

for x in c:
    print(x)
# Out:
# 3
# 2
# 1

# %%
c = Countdown(3)

it1 = iter(c)
it2 = iter(c)

print(next(it1))
print(next(it2))
print(next(it1))
# Out:
# 3
# 2
# 1

# %%
class Reverse:
    """Iterator for looping over a sequence backwards."""
    def __init__(self, data):
        self.data = data
        self.index = len(data)

    def __iter__(self):
        return self

    def __next__(self):
        if self.index == 0:
            raise StopIteration
        self.index = self.index - 1
        return self.data[self.index]
r = Reverse([1,2,3])
r.data 
r.index
# Out:
# 3

# %%
def test():
    yield 1
test()
# Out:
# <generator object test at 0x000001E64B9CE2D0>

# %%
def reverse(data):
    for index in range(len(data)-1, -1, -1):
        yield data[index]
r = reverse("golf")
next(r)
next(r)
# Out:
# 'l'

# %%
for char in reverse('golf'):
    print(char)
# Out:
# f
# l
# o
# g

# %%
sum(i*i for i in range(10))
# Out:
# 285

# %%
xvec = [10, 20, 30]
yvec = [7, 5, 3]
sum(x*y for x,y in zip(xvec, yvec))
# Out:
# 260

# %%
data = 'golf'
list(data[i] for i in range(len(data)-1, -1, -1))
# Out:
# ['f', 'l', 'o', 'g']

# %%
page = open('data.txt')
unique_words = set(word for line in page  for word in line.split())
unique_words
# Out:
# {'21',
#  'GU.',
#  'Good',
#  'Morning!',
#  'My',
#  'age',
#  'am',
#  'and',
#  'bsc',
#  'data',
#  'dhruvita',
#  'from',
#  'graduated',
#  'hello',
#  'i',
#  'insight',
#  'is',
#  'it',
#  'management',
#  'my',
#  'n',
#  'name',
#  'recently',
#  'visual'}

# %%
class Student:
    def __init__(self, name, gpa):
        self.name = name
        self.gpa = gpa

graduates = [
    Student("Amit", 8.5),
    Student("Riya", 9.2),
    Student("Kabir", 8.9)
]
valedictorian = max((student.gpa, student.name) for student in graduates)
valedictorian
# Out:
# (9.2, 'Riya')
